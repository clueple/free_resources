# %%
import numpy as np
import skimage
skimage.__version__
from skimage import measure, filters
from skimage import io
from skimage.restoration import denoise_bilateral, estimate_sigma, denoise_tv_chambolle, denoise_wavelet
from skimage.util import img_as_float
from matplotlib import pyplot as plt

file = r'f:/001_png.png'
img = io.imread(file, as_gray=True)

# %%
from PIL import Image

pil_img = Image.open(file)

# %%
np_pil_img = np.array(pil_img)

sk_np_img = img_as_float(np_pil_img)

plt.imshow(sk_np_img)
